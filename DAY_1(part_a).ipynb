# %%
import pandas as pd
df=pd.read_csv("/content/Zudio_sales_data.csv")

# %%
df.describe()
# Out:
#        Store Number    Postal Code  Selling Area Size (sq ft)  Staff Count  \
# count   7899.000000    7899.000000                7899.000000  7899.000000
# mean      50.666034  419982.374984                1112.077478    11.504747
# std       29.095274   11695.237817                 193.239371     5.194722
# min        1.000000  400006.000000                 800.000000     3.000000
# 25%       25.000000  409841.000000                 950.000000     7.000000
# 50%       51.000000  419988.000000                1100.000000    12.000000
# 75%       76.000000  430258.000000                1300.000000    16.000000
# max      100.000000  439985.000000                1400.000000    20.000000
#
#            Order ID    Customer ID   Product ID        Price     Quantity  \
# count   7899.000000    7899.000000  7899.000000  7899.000000  7899.000000
# mean   54920.719965  549440.714521   602.069376  1761.113432     4.519433
# ...

# %%
df.columns
# Out:
# Index(['Store', 'Country', 'State', 'City', 'Category', 'Clothing Type',
#        'Store Number', 'Postal Code', 'Store Type', 'Store Open Date',
#        'Selling Area Size (sq ft)', 'Store Manager', 'Manager ID',
#        'Store Address', 'Contact Information', 'Operating Hours',
#        'Staff Count', 'Parking Availability', 'Security Features', 'Order ID',
#        'Order Date', 'Month', 'Customer ID', 'Customer Name', 'Product ID',
#        'Price', 'Quantity', 'Sales Profit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7899 entries, 0 to 7898
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      7899 non-null   object
#  1   Country                    7899 non-null   object
#  2   State                      7899 non-null   object
#  3   City                       7899 non-null   object
#  4   Category                   7899 non-null   object
#  5   Clothing Type              7899 non-null   object
#  6   Store Number               7899 non-null   int64
#  7   Postal Code                7899 non-null   int64
#  8   Store Type                 7899 non-null   object
#  9   Store Open Date            7899 non-null   object
#  10  Selling Area Size (sq ft)  7899 non-null   int64
#  11  Store Manager              7899 non-null   object
#  12  Manager ID                 7899 non-null   object
# ...

# %%
df.dtypes
# Out:
# Store                         object
# Country                       object
# State                         object
# City                          object
# Category                      object
# Clothing Type                 object
# Store Number                   int64
# Postal Code                    int64
# Store Type                    object
# Store Open Date               object
# Selling Area Size (sq ft)      int64
# Store Manager                 object
# Manager ID                    object
# Store Address                 object
# Contact Information           object
# Operating Hours               object
# Staff Count                    int64
# Parking Availability          object
# Security Features             object
# Order ID                       int64
# Order Date                    object
# Month                         object
# Customer ID                    int64
# Customer Name                 object
# Product ID                     int64
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7899, step=1)

# %%
df.isnull().sum()
# Out:
# Store                           0
# Country                         0
# State                           0
# City                            0
# Category                        0
# Clothing Type                   0
# Store Number                    0
# Postal Code                     0
# Store Type                      0
# Store Open Date                 0
# Selling Area Size (sq ft)       0
# Store Manager                   0
# Manager ID                      0
# Store Address                   0
# Contact Information             0
# Operating Hours                 0
# Staff Count                     0
# Parking Availability            0
# Security Features            2038
# Order ID                        0
# Order Date                      0
# Month                           0
# Customer ID                     0
# Customer Name                   0
# Product ID                      0
# Price                           0
# Quantity                        0
# ...

# %%
df["State"].unique()
# Out:
# array(['Karnataka', 'Gujarat', 'Uttar Pradesh', 'West Bengal',
#        'Maharashtra', 'Tamil Nadu', 'Rajasthan', 'Delhi'], dtype=object)

# %%
df["State"].value_counts(normalize=True)
# Out:
# State
# Rajasthan        0.128244
# Uttar Pradesh    0.127991
# Delhi            0.127991
# Gujarat          0.124320
# West Bengal      0.124320
# Maharashtra      0.123433
# Karnataka        0.121914
# Tamil Nadu       0.121788
# Name: proportion, dtype: float64

# %%
df.head(1000)
# Out:
#      Store Country          State        City Category Clothing Type  \
# 0    Zudio   India      Karnataka       Jalna    Women       Dresses
# 1    Zudio   India        Gujarat       Patna     Kids        Skirts
# 2    Zudio   India  Uttar Pradesh     Kolkata      Men       Hoodies
# 3    Zudio   India    West Bengal     Kolkata    Women       Dresses
# 4    Zudio   India    West Bengal    Guwahati      Men       Dresses
# ..     ...     ...            ...         ...      ...           ...
# 995  Zudio   India    West Bengal      Mumbai      Men         Shoes
# 996  Zudio   India  Uttar Pradesh     Madurai      Men         Jeans
# 997  Zudio   India      Karnataka   New Delhi    Women      T-shirts
# 998  Zudio   India      Karnataka      Rajkot    Women        Skirts
# 999  Zudio   India    West Bengal  Coimbatore    Women         Shoes
#
#      Store Number  Postal Code Store Type Store Open Date  ...  \
# 0              30       411084      Owned      2022-06-04  ...
# ...

# %%
df.tail(25)
# Out:
#       Store Country          State           City Category Clothing Type  \
# 7874  Zudio   India    Maharashtra         Mumbai      Men        Shirts
# 7875  Zudio   India    West Bengal       Varanasi     Kids       Dresses
# 7876  Zudio   India  Uttar Pradesh         Rajkot      Men          Tops
# 7877  Zudio   India        Gujarat        Solapur     Kids       Dresses
# 7878  Zudio   India  Uttar Pradesh       Varanasi     Kids         Jeans
# 7879  Zudio   India    Maharashtra      New Delhi    Women         Jeans
# 7880  Zudio   India      Karnataka      Hyderabad     Kids         Pants
# 7881  Zudio   India    Maharashtra         Indore     Kids       Jackets
# 7882  Zudio   India  Uttar Pradesh           Pune     Kids      Sweaters
# 7883  Zudio   India        Gujarat  Visakhapatnam     Kids         Jeans
# 7884  Zudio   India          Delhi         Ranchi    Women       Dresses
# 7885  Zudio   India     Tamil Nadu      Bengaluru     Kids       Dresses
# ...

# %%
df.shape
# Out:
# (7899, 28)

# %%
df[['State','City']]
# Out:
#               State        City
# 0         Karnataka       Jalna
# 1           Gujarat       Patna
# 2     Uttar Pradesh     Kolkata
# 3       West Bengal     Kolkata
# 4       West Bengal    Guwahati
# ...             ...         ...
# 7894  Uttar Pradesh  Chandigarh
# 7895  Uttar Pradesh  Aurangabad
# 7896     Tamil Nadu        Pune
# 7897          Delhi     Madurai
# 7898        Gujarat   Bengaluru
#
# [7899 rows x 2 columns]
